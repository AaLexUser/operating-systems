# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./csv/schedpolicy-pidstat.csv', delimiter=";")
df.head()
# Out:
#        Time  UID     PID  prio  policy    Command
# 0  23:26:40    0  233911     0    IDLE  stress-ng
# 1  23:26:41    0  233911     0  DEADLN  stress-ng
# 2  23:26:42    0  233911     0  DEADLN  stress-ng
# 3  23:26:43    0  233911     0  DEADLN  stress-ng
# 4  23:26:44    0  233911     0  DEADLN  stress-ng

# %%
df['Time'] = pd.to_datetime(df['Time'])
df
# Out:
#                    Time  UID     PID  prio  policy    Command
# 0   2023-11-19 23:26:40    0  233911     0    IDLE  stress-ng
# 1   2023-11-19 23:26:41    0  233911     0  DEADLN  stress-ng
# 2   2023-11-19 23:26:42    0  233911     0  DEADLN  stress-ng
# 3   2023-11-19 23:26:43    0  233911     0  DEADLN  stress-ng
# 4   2023-11-19 23:26:44    0  233911     0  DEADLN  stress-ng
# ..                  ...  ...     ...   ...     ...        ...
# 591 2023-11-19 23:36:32    0  233911     0  DEADLN  stress-ng
# 592 2023-11-19 23:36:33    0  233911     0  DEADLN  stress-ng
# 593 2023-11-19 23:36:34    0  233911     0  DEADLN  stress-ng
# 594 2023-11-19 23:36:35    0  233911     0  DEADLN  stress-ng
# 595 2023-11-19 23:36:36    0  233911     0  DEADLN  stress-ng
#
# [596 rows x 6 columns]

# %%
plt.figure(figsize=(10,6))
plt.scatter(df['Time'], df['policy'])
plt.xlabel('Time')
plt.ylabel('Policy')
plt.grid(True)
plt.minorticks_on()
plt.grid(which='minor', linestyle='-', color='#999999', alpha=0.2)
plt.title('Policy over Time')
plt.savefig('./image/schedpolicy-pidstat.png')
plt.show()
