# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./csv/netlink-task-bogops.csv', delimiter=";")
df['sys+user'] = df['usr_time'] + df['sys_time']
df.head()
# Out:
#    netlink-task  bogo_ops  real_time  usr_time  sys_time  bogo_ops/s_real  \
# 0             1   9088594       30.0      7.16     22.83        302953.21
# 1             2  16816719       30.0     13.42     46.56        560554.64
# 2             3  21557714       30.0     16.90     73.05        718588.73
# 3             4  19037412       30.0     15.72    104.18        634578.24
# 4             5  15973222       30.0     13.99    135.78        532412.73
#
#    bogo_ops/s_user+sys  CPU_used_per  sys+user
# 0            303054.15         99.97     29.99
# 1            280372.11         99.97     59.98
# 2            239663.30         99.94     89.95
# 3            158777.41         99.92    119.90
# 4            106651.68         99.84    149.77

# %%
x_column = 'netlink-task'
fig, axs = plt.subplots(3, 2, figsize=(20,15))
maxs = [df[col].max() for col in df.columns] 
means = [df[col].mean() for col in df.columns] 
mins = [df[col].min() for col in df.columns] 

axs[0,0].plot(df[x_column], df['bogo_ops'])
axs[0,0].set_xlabel(x_column)
axs[0,0].set_ylabel('Bogo ops')
axs[0,0].set_title('Bogo ops over ' + x_column)

axs[0,1].plot(df[x_column], df['bogo_ops/s_real'])
axs[0,1].set_xlabel(x_column)
axs[0,1].set_ylabel('Bogo ops/s (real time)')
axs[0,1].set_title('Bogo ops/s over ' + x_column)

axs[1,0].plot(df[x_column], df['bogo_ops/s_user+sys'])
axs[1,0].set_xlabel(x_column)
axs[1,0].set_ylabel('Bogo ops/s (sys+user)')
axs[1,0].set_title('Bogo ops/s over ' + x_column)

axs[1,1].plot(df[x_column], df['CPU_used_per'])
axs[1,1].set_xlabel(x_column)
axs[1,1].set_ylabel('CPU used per')
axs[1,1].set_title('CPU used over ' + x_column)

axs[2,0].plot(df[x_column], df['real_time'])
axs[2,0].set_xlabel(x_column)
axs[2,0].set_ylabel('Real Time')
axs[2,0].set_title('Real Time over ' + x_column)

axs[2,1].plot(df[x_column], df['sys+user'])
axs[2,1].set_xlabel(x_column)
axs[2,1].set_ylabel('Sys + User Time')
axs[2,1].set_title('Sys + User Time over ' + x_column)

for i in range(3):
    for j in range(2):
        axs[i,j].grid(True)
        axs[i,j].minorticks_on()
        axs[i,j].grid(which='minor', linestyle='-', color='#999999', alpha=0.2)

plt.savefig('./image/netlink-task-bogops.png')
plt.show()

# %%
df = pd.read_csv('./csv/netdev-bogops.csv', delimiter=";")
df['sys+user'] = df['usr_time'] + df['sys_time']
df.head()
# Out:
#    netdev  bogo_ops  real_time  usr_time  sys_time  bogo_ops/s_real  \
# 0       1   2117653       30.0     14.69     15.28         70584.17
# 1       2   4284132       30.0     28.56     31.41        142804.32
# 2       3   6138269       30.0     41.31     48.62        204608.05
# 3       4   7781851       30.0     53.86     66.08        259395.36
# 4       5   7706982       30.0     63.84     85.89        256857.43
#
#    bogo_ops/s_user+sys  CPU_used_per  sys+user
# 0             70659.09         99.89     29.97
# 1             71437.92         99.95     59.97
# 2             68256.08         99.92     89.93
# 3             64881.20         99.95    119.94
# 4             51472.53         99.80    149.73

# %%
x_column = 'netdev'
fig, axs = plt.subplots(3, 2, figsize=(20,15))
maxs = [df[col].max() for col in df.columns] 
means = [df[col].mean() for col in df.columns] 
mins = [df[col].min() for col in df.columns] 

axs[0,0].plot(df[x_column], df['bogo_ops'])
axs[0,0].set_xlabel(x_column)
axs[0,0].set_ylabel('Bogo ops')
axs[0,0].set_title('Bogo ops over ' + x_column)

axs[0,1].plot(df[x_column], df['bogo_ops/s_real'])
axs[0,1].set_xlabel(x_column)
axs[0,1].set_ylabel('Bogo ops/s (real time)')
axs[0,1].set_title('Bogo ops/s over ' + x_column)

axs[1,0].plot(df[x_column], df['bogo_ops/s_user+sys'])
axs[1,0].set_xlabel(x_column)
axs[1,0].set_ylabel('Bogo ops/s (sys+user)')
axs[1,0].set_title('Bogo ops/s over ' + x_column)

axs[1,1].plot(df[x_column], df['CPU_used_per'])
axs[1,1].set_xlabel(x_column)
axs[1,1].set_ylabel('CPU used per')
axs[1,1].set_title('CPU used over ' + x_column)

axs[2,0].plot(df[x_column], df['real_time'])
axs[2,0].set_xlabel(x_column)
axs[2,0].set_ylabel('Real Time')
axs[2,0].set_title('Real Time over ' + x_column)

axs[2,1].plot(df[x_column], df['sys+user'])
axs[2,1].set_xlabel(x_column)
axs[2,1].set_ylabel('Sys + User Time')
axs[2,1].set_title('Sys + User Time over ' + x_column)

for i in range(3):
    for j in range(2):
        axs[i,j].grid(True)
        axs[i,j].minorticks_on()
        axs[i,j].grid(which='minor', linestyle='-', color='#999999', alpha=0.2)

plt.savefig('./image/netdev-bogops.png')
plt.show()

# %%
df = pd.read_csv('./csv/netlink-proc.csv', delimiter=";")
df['sys+user'] = df['usr_time'] + df['sys_time']
df.head()
# Out:
#    netlink  bogo_ops  real_time  usr_time  sys_time  bogo_ops/s_real  \
# 0  netlink     11701      30.01     46.94     32.67           389.89
# 1  netlink     14710      30.01     57.29     24.43           490.23
# 2  netlink     14920      30.00     57.53     24.00           497.27
# 3  netlink     13475      30.04     53.06     27.35           448.57
# 4  netlink     13810      30.01     55.14     25.15           460.12
#
#    bogo_ops/s_user+sys  CPU_used_per  sys+user
# 0               146.98         53.05     79.61
# 1               180.00         54.47     81.72
# 2               183.00         54.35     81.53
# 3               167.58         53.54     80.41
# 4               172.00         53.50     80.29

# %%
plt.figure(figsize=(10,6))
plt.plot(df[df['netlink'] == 'netlink']['bogo_ops'])
plt.plot(df[df['netlink'] == 'netlink']['bogo_ops'], marker='.', markersize=10)
plt.axhline(df[df['netlink'] == 'empty']['bogo_ops'].mean(), linestyle='--', color='g', label='Mean: {:.2f}'.format(df[df['netlink'] == 'empty']['bogo_ops'].mean()))
plt.plot(df[df['netlink'] == 'empty']['bogo_ops'])
plt.plot(df[df['netlink'] == 'empty']['bogo_ops'], marker='.', markersize=10)
plt.axhline(df[df['netlink'] == 'netlink']['bogo_ops'].mean(), linestyle='--', color='r', label='Mean: {:.2f}'.format(df[df['netlink'] == 'netlink']['bogo_ops'].mean()))
plt.xlabel('Time')
plt.ylabel('Bogo ops')
plt.grid(True)
plt.minorticks_on()
plt.grid(which='minor', linestyle='-', color='#999999', alpha=0.2)
plt.title('Bogo ops % over Time')
plt.legend()
plt.savefig('./image/netlink-proc.png')
plt.show()
